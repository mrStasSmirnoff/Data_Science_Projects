# %%
import warnings                           
warnings.filterwarnings('ignore')

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import lag_plot
from itertools import product
from tqdm import tqdm_notebook

# %matplotlib inline

from utils import mean_absolute_percentage_error, timeseries_train_test_split, train_test_split

from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

# %%
data = pd.read_excel('./data/день - количество блюд.xlsx', skiprows= 3, usecols= [0,1], names = ['date', 'meals'])
data.head()
# Out:
#                   date  meals
# 0  2018-04-06 00:00:00   32.0
# 1  2018-04-07 00:00:00    8.0
# 2  2018-04-08 00:00:00    4.0
# 3  2018-04-09 00:00:00   14.0
# 4  2018-04-10 00:00:00    5.0

# %%
# remove the last row
data = data.iloc[:-1]

# %%
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')
data.head()
# Out:
#             meals
# date
# 2018-04-06   32.0
# 2018-04-07    8.0
# 2018-04-08    4.0
# 2018-04-09   14.0
# 2018-04-10    5.0

# %%
plt.figure(figsize=(15,7))
plt.plot(data)
plt.title('Meals consumption by day')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
lag_plot(data)
plt.title('Meals consumption lag plot')
plt.grid(True)
plt.show()

# %%
time_data = pd.DataFrame(data.meals.copy())
time_data.columns = ["target"]

# %%
# Adding the lag of the target varable from 7 steps back (week) up to 30 (month)

for i in range(1, 21):
    time_data["lag_{}".format(i)] = time_data.target.shift(i)

# %%
time_data.tail(10)
# Out:
#             target  lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# date
# 2020-09-12   106.0  122.0  143.0  122.0  133.0  149.0  102.0  101.0  131.0
# 2020-09-13   113.0  106.0  122.0  143.0  122.0  133.0  149.0  102.0  101.0
# 2020-09-14   125.0  113.0  106.0  122.0  143.0  122.0  133.0  149.0  102.0
# 2020-09-15   130.0  125.0  113.0  106.0  122.0  143.0  122.0  133.0  149.0
# 2020-09-16   144.0  130.0  125.0  113.0  106.0  122.0  143.0  122.0  133.0
# 2020-09-17   136.0  144.0  130.0  125.0  113.0  106.0  122.0  143.0  122.0
# 2020-09-18   123.0  136.0  144.0  130.0  125.0  113.0  106.0  122.0  143.0
# 2020-09-19   110.0  123.0  136.0  144.0  130.0  125.0  113.0  106.0  122.0
# 2020-09-20   120.0  110.0  123.0  136.0  144.0  130.0  125.0  113.0  106.0
# 2020-09-21    93.0  120.0  110.0  123.0  136.0  144.0  130.0  125.0  113.0
#
#             lag_9  ...  lag_11  lag_12  lag_13  lag_14  lag_15  lag_16  \
# date               ...
# 2020-09-12  138.0  ...   111.0   110.0   105.0    91.0   101.0    95.0
# 2020-09-13  131.0  ...   131.0   111.0   110.0   105.0    91.0   101.0
# 2020-09-14  101.0  ...   138.0   131.0   111.0   110.0   105.0    91.0
# 2020-09-15  102.0  ...   131.0   138.0   131.0   111.0   110.0   105.0
# 2020-09-16  149.0  ...   101.0   131.0   138.0   131.0   111.0   110.0
# 2020-09-17  133.0  ...   102.0   101.0   131.0   138.0   131.0   111.0
# 2020-09-18  122.0  ...   149.0   102.0   101.0   131.0   138.0   131.0
# 2020-09-19  143.0  ...   133.0   149.0   102.0   101.0   131.0   138.0
# 2020-09-20  122.0  ...   122.0   133.0   149.0   102.0   101.0   131.0
# 2020-09-21  106.0  ...   143.0   122.0   133.0   149.0   102.0   101.0
#
#             lag_17  lag_18  lag_19  lag_20
# date
# 2020-09-12   113.0   109.0   110.0   122.0
# 2020-09-13    95.0   113.0   109.0   110.0
# 2020-09-14   101.0    95.0   113.0   109.0
# 2020-09-15    91.0   101.0    95.0   113.0
# 2020-09-16   105.0    91.0   101.0    95.0
# 2020-09-17   110.0   105.0    91.0   101.0
# 2020-09-18   111.0   110.0   105.0    91.0
# 2020-09-19   131.0   111.0   110.0   105.0
# 2020-09-20   138.0   131.0   111.0   110.0
# 2020-09-21   131.0   138.0   131.0   111.0
#
# [10 rows x 21 columns]

# %%
time_data.shape
# Out:
# (897, 21)

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
X_train, X_test, y_train, y_test = train_test_split(time_data)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (613, 20) (264, 20)

# %%
def linear_regression_model(X_train, y_train):
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    
    return lr

# %%
print(X_train.shape, y_train.shape)
# Out:
# (613, 20) (613,)

# %%
lr = linear_regression_model(X_train, y_train)

# %%
def plotModelResults(model, X_train, X_test, plot_intervals=False, plot_anomalies=False):
    """
        Plots modelled vs fact values, prediction intervals and anomalies
    
    """
    
    prediction = model.predict(X_test)
    
    plt.figure(figsize=(15, 7))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_test.values, label="actual", linewidth=2.0)
    
    if plot_intervals:
        cv = cross_val_score(model, X_train, y_train, 
                                    cv=tscv, 
                                    scoring="neg_mean_absolute_error")
        mae = cv.mean() * (-1)
        deviation = cv.std()
        
        scale = 1.96
        lower = prediction - (mae + scale * deviation)
        upper = prediction + (mae + scale * deviation)
        
        plt.plot(lower, "r--", label="upper bond / lower bond", alpha=0.5)
        plt.plot(upper, "r--", alpha=0.5)
        
        if plot_anomalies:
            anomalies = np.array([np.NaN]*len(y_test))
            anomalies[y_test<lower] = y_test[y_test<lower]
            anomalies[y_test>upper] = y_test[y_test>upper]
            plt.plot(anomalies, "o", markersize=10, label = "Anomalies")
    
    error = mean_absolute_percentage_error(prediction, y_test)
    plt.title("Mean absolute percentage error {0:.2f}%".format(error))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);
    
def plotCoefficients(model):
    """
        Plots sorted coefficient values of the model
    """
    
    coefs = pd.DataFrame(model.coef_, X_train.columns)
    coefs.columns = ["coef"]
    coefs["abs"] = coefs.coef.apply(np.abs)
    coefs = coefs.sort_values(by="abs", ascending=False).drop(["abs"], axis=1)
    
    plt.figure(figsize=(15, 7))
    coefs.coef.plot(kind='bar')
    plt.grid(True, axis='y')
    plt.hlines(y=0, xmin=0, xmax=len(coefs), linestyles='dashed');

# %%
plotModelResults(lr, X_train, X_test, plot_intervals=True)
plotCoefficients(lr)

# %% [markdown]
# ### Regularization and feature selection

# %%
sns.heatmap(X_train.corr());

# %%
from sklearn.linear_model import LassoCV, RidgeCV

ridge = RidgeCV(cv=tscv)
ridge.fit(X_train, y_train)

plotModelResults(ridge, 
                 X_train=X_train, 
                 X_test=X_test, 
                 plot_intervals=True, plot_anomalies=True)
plotCoefficients(ridge)

# %%
lasso = LassoCV(cv=tscv)
lasso.fit(X_train, y_train)

plotModelResults(lasso, 
                 X_train=X_train, 
                 X_test=X_test, 
                 plot_intervals=True, plot_anomalies=True)
plotCoefficients(lasso)
